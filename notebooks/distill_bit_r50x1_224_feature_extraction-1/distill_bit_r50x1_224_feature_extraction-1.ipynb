# %%
import os

assert os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] == "true"
assert os.environ["CUDA_DEVICE_ORDER"] == "PCI_BUS_ID"
assert os.environ["CUDA_VISIBLE_DEVICES"]

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import tensorflow_hub as tf_hub
from pathlib import Path
from sklearn.model_selection import train_test_split

# %%
GPU_BUS_ID = 1
BATCH_SIZE = 128
IMG_HEIGHT = 224
IMG_WIDTH = 224
PREPROCESS_SEED = 123

# %%
base_data_dir = Path("..", "..", "input", "arch-recognizer-dataset").absolute()
train_data_dir = base_data_dir / "train"
test_data_dir = base_data_dir / "test"

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    labels="inferred",
    label_mode="int",
    validation_split=0.2,
    subset="training",
    seed=PREPROCESS_SEED,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    labels="inferred",
    label_mode="int",
    validation_split=0.2,
    subset="validation",
    seed=PREPROCESS_SEED,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_data_dir,
    labels="inferred",
    label_mode="int",
    seed=PREPROCESS_SEED,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
)
class_names = train_ds.class_names
train_ds = (
    train_ds.cache()
    .shuffle(1000)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)
val_ds = (
    val_ds.cache()
    .shuffle(1000)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)
test_ds = (
    val_ds.cache()
    .shuffle(1000)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)
# Out:
# Found 9101 files belonging to 25 classes.
# Using 7281 files for training.
# Found 9101 files belonging to 25 classes.
# Using 1820 files for validation.
# Found 1012 files belonging to 25 classes.

# %%
def create_model():
    _model = tf.keras.models.Sequential(
        [
            tf.keras.layers.experimental.preprocessing.RandomFlip(
                "horizontal", input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)
            ),
            tf.keras.layers.experimental.preprocessing.RandomZoom(0.3),
            tf.keras.layers.experimental.preprocessing.Rescaling(
                1.0 / 255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)
            ),
            tf_hub.KerasLayer(
                "https://tfhub.dev/sayakpaul/distill_bit_r50x1_224_feature_extraction/1",
                trainable=False,
            ),
            tf.keras.layers.Dense(len(class_names)),
        ]
    )
    _model.compile(
        optimizer="adam",
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"],
    )
    return _model

# %%
# Create a callback that saves the model's weights periodically
cp_dir = Path("checkpoints")
cp_path = cp_dir / "cp-{epoch:04d}.ckpt"
model = create_model()

# Load checkpoint if found
latest_cp = tf.train.latest_checkpoint(cp_dir)
if latest_cp:
    model.load_weights(latest_cp)
    restored_test_loss, restored_test_acc = model.evaluate(test_ds, verbose=2)
    print(f"Restored model test accuracy: {restored_test_acc}")
    
# Train
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=80,
    callbacks=[
        tf.keras.callbacks.ModelCheckpoint(
            filepath=str(cp_path),
            verbose=1,
            save_weights_only=True,
            save_freq=BATCH_SIZE,
        ),
        tf.keras.callbacks.EarlyStopping(
            min_delta=0.0001, patience=10, restore_best_weights=True
        ),
    ],
)
# Out:
# 15/15 - 20s - loss: 1.1197 - accuracy: 0.6396
# Restored model test accuracy: 0.6395604610443115
# Epoch 1/80
# 57/57 [==============================] - 88s 1s/step - loss: 1.0976 - accuracy: 0.6838 - val_loss: 1.1004 - val_accuracy: 0.6484
# Epoch 2/80
# 57/57 [==============================] - 64s 1s/step - loss: 1.0756 - accuracy: 0.6892 - val_loss: 1.0874 - val_accuracy: 0.6533
# Epoch 3/80
# 14/57 [======>.......................] - ETA: 38s - loss: 1.0332 - accuracy: 0.7023
# Epoch 00003: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0003.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 1.0416 - accuracy: 0.7007 - val_loss: 1.0729 - val_accuracy: 0.6593
# Epoch 4/80
# 57/57 [==============================] - 64s 1s/step - loss: 1.0233 - accuracy: 0.6999 - val_loss: 1.0600 - val_accuracy: 0.6588
# Epoch 5/80
# 28/57 [=============>................] - ETA: 26s - loss: 0.9922 - accuracy: 0.7120
# Epoch 00005: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0005.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.9971 - accuracy: 0.7080 - val_loss: 1.0504 - val_accuracy: 0.6648
# Epoch 6/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.9798 - accuracy: 0.7091 - val_loss: 1.0373 - val_accuracy: 0.6588
# Epoch 7/80
# 42/57 [=====================>........] - ETA: 13s - loss: 0.9497 - accuracy: 0.7196
# Epoch 00007: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0007.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.9549 - accuracy: 0.7201 - val_loss: 1.0326 - val_accuracy: 0.6665
# Epoch 8/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.9436 - accuracy: 0.7219 - val_loss: 1.0295 - val_accuracy: 0.6714
# Epoch 9/80
# 56/57 [============================>.] - ETA: 0s - loss: 0.9225 - accuracy: 0.7292
# Epoch 00009: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0009.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.9221 - accuracy: 0.7297 - val_loss: 1.0115 - val_accuracy: 0.6725
# Epoch 10/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.9121 - accuracy: 0.7325 - val_loss: 1.0161 - val_accuracy: 0.6753
# Epoch 11/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.8887 - accuracy: 0.7364 - val_loss: 1.0135 - val_accuracy: 0.6720
# Epoch 12/80
# 13/57 [=====>........................] - ETA: 39s - loss: 0.8818 - accuracy: 0.7506
# Epoch 00012: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0012.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.8823 - accuracy: 0.7395 - val_loss: 1.0094 - val_accuracy: 0.6780
# Epoch 13/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.8691 - accuracy: 0.7462 - val_loss: 0.9982 - val_accuracy: 0.6841
# Epoch 14/80
# 27/57 [=============>................] - ETA: 27s - loss: 0.8633 - accuracy: 0.7436
# Epoch 00014: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0014.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.8539 - accuracy: 0.7506 - val_loss: 0.9913 - val_accuracy: 0.6802
# Epoch 15/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.8411 - accuracy: 0.7568 - val_loss: 0.9864 - val_accuracy: 0.6890
# Epoch 16/80
# 41/57 [====================>.........] - ETA: 14s - loss: 0.8320 - accuracy: 0.7591
# Epoch 00016: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0016.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.8338 - accuracy: 0.7557 - val_loss: 0.9847 - val_accuracy: 0.6868
# Epoch 17/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.8245 - accuracy: 0.7551 - val_loss: 0.9890 - val_accuracy: 0.6780
# Epoch 18/80
# 55/57 [===========================>..] - ETA: 1s - loss: 0.8059 - accuracy: 0.7674
# Epoch 00018: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0018.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.8066 - accuracy: 0.7667 - val_loss: 0.9789 - val_accuracy: 0.6852
# Epoch 19/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.7998 - accuracy: 0.7683 - val_loss: 0.9802 - val_accuracy: 0.6786
# Epoch 20/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.7910 - accuracy: 0.7702 - val_loss: 0.9766 - val_accuracy: 0.6830
# Epoch 21/80
# 12/57 [=====>........................] - ETA: 40s - loss: 0.7987 - accuracy: 0.7620
# Epoch 00021: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0021.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.7887 - accuracy: 0.7695 - val_loss: 0.9760 - val_accuracy: 0.6808
# Epoch 22/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.7760 - accuracy: 0.7723 - val_loss: 0.9708 - val_accuracy: 0.6846
# Epoch 23/80
# 26/57 [============>.................] - ETA: 27s - loss: 0.7656 - accuracy: 0.7763
# Epoch 00023: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0023.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.7611 - accuracy: 0.7771 - val_loss: 0.9754 - val_accuracy: 0.6868
# Epoch 24/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.7528 - accuracy: 0.7779 - val_loss: 0.9604 - val_accuracy: 0.6918
# Epoch 25/80
# 40/57 [====================>.........] - ETA: 15s - loss: 0.7358 - accuracy: 0.7830
# Epoch 00025: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0025.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.7451 - accuracy: 0.7824 - val_loss: 0.9686 - val_accuracy: 0.6907
# Epoch 26/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.7400 - accuracy: 0.7841 - val_loss: 0.9618 - val_accuracy: 0.6907
# Epoch 27/80
# 54/57 [===========================>..] - ETA: 2s - loss: 0.7292 - accuracy: 0.7860
# Epoch 00027: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0027.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.7316 - accuracy: 0.7849 - val_loss: 0.9619 - val_accuracy: 0.6923
# Epoch 28/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.7233 - accuracy: 0.7895 - val_loss: 0.9678 - val_accuracy: 0.6896
# Epoch 29/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.7185 - accuracy: 0.7932 - val_loss: 0.9600 - val_accuracy: 0.6940
# Epoch 30/80
# 11/57 [====>.........................] - ETA: 41s - loss: 0.6817 - accuracy: 0.7976
# Epoch 00030: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0030.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.7104 - accuracy: 0.7904 - val_loss: 0.9568 - val_accuracy: 0.6945
# Epoch 31/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.7051 - accuracy: 0.7976 - val_loss: 0.9650 - val_accuracy: 0.6868
# Epoch 32/80
# 25/57 [============>.................] - ETA: 28s - loss: 0.7068 - accuracy: 0.7947
# Epoch 00032: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0032.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6992 - accuracy: 0.7956 - val_loss: 0.9691 - val_accuracy: 0.6846
# Epoch 33/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6935 - accuracy: 0.7995 - val_loss: 0.9571 - val_accuracy: 0.6918
# Epoch 34/80
# 39/57 [===================>..........] - ETA: 16s - loss: 0.6869 - accuracy: 0.7987
# Epoch 00034: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0034.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6816 - accuracy: 0.8024 - val_loss: 0.9516 - val_accuracy: 0.6984
# Epoch 35/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6786 - accuracy: 0.8024 - val_loss: 0.9632 - val_accuracy: 0.6890
# Epoch 36/80
# 53/57 [==========================>...] - ETA: 3s - loss: 0.6768 - accuracy: 0.8066
# Epoch 00036: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0036.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6792 - accuracy: 0.8046 - val_loss: 0.9569 - val_accuracy: 0.6973
# Epoch 37/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6641 - accuracy: 0.8088 - val_loss: 0.9521 - val_accuracy: 0.6973
# Epoch 38/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6601 - accuracy: 0.8096 - val_loss: 0.9542 - val_accuracy: 0.6929
# Epoch 39/80
# 10/57 [====>.........................] - ETA: 42s - loss: 0.6564 - accuracy: 0.8071
# Epoch 00039: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0039.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6619 - accuracy: 0.8074 - val_loss: 0.9532 - val_accuracy: 0.6945
# Epoch 40/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6525 - accuracy: 0.8162 - val_loss: 0.9483 - val_accuracy: 0.6989
# Epoch 41/80
# 24/57 [===========>..................] - ETA: 29s - loss: 0.6297 - accuracy: 0.8224
# Epoch 00041: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0041.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6450 - accuracy: 0.8132 - val_loss: 0.9455 - val_accuracy: 0.6984
# Epoch 42/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6402 - accuracy: 0.8135 - val_loss: 0.9529 - val_accuracy: 0.6956
# Epoch 43/80
# 38/57 [===================>..........] - ETA: 17s - loss: 0.6348 - accuracy: 0.8202
# Epoch 00043: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0043.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6443 - accuracy: 0.8121 - val_loss: 0.9492 - val_accuracy: 0.7022
# Epoch 44/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6372 - accuracy: 0.8187 - val_loss: 0.9521 - val_accuracy: 0.6989
# Epoch 45/80
# 52/57 [==========================>...] - ETA: 4s - loss: 0.6174 - accuracy: 0.8262
# Epoch 00045: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0045.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6182 - accuracy: 0.8256 - val_loss: 0.9495 - val_accuracy: 0.6995
# Epoch 46/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6221 - accuracy: 0.8223 - val_loss: 0.9521 - val_accuracy: 0.6967
# Epoch 47/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6132 - accuracy: 0.8263 - val_loss: 0.9514 - val_accuracy: 0.7011
# Epoch 48/80
#  9/57 [===>..........................] - ETA: 43s - loss: 0.6158 - accuracy: 0.8359
# Epoch 00048: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0048.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6123 - accuracy: 0.8287 - val_loss: 0.9486 - val_accuracy: 0.7038
# Epoch 49/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.6122 - accuracy: 0.8226 - val_loss: 0.9441 - val_accuracy: 0.7060
# Epoch 50/80
# 23/57 [===========>..................] - ETA: 30s - loss: 0.5913 - accuracy: 0.8305
# Epoch 00050: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0050.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.6038 - accuracy: 0.8290 - val_loss: 0.9608 - val_accuracy: 0.6984
# Epoch 51/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.5965 - accuracy: 0.8305 - val_loss: 0.9469 - val_accuracy: 0.7088
# Epoch 52/80
# 37/57 [==================>...........] - ETA: 18s - loss: 0.5935 - accuracy: 0.8296
# Epoch 00052: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0052.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.5967 - accuracy: 0.8283 - val_loss: 0.9555 - val_accuracy: 0.6962
# Epoch 53/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.5871 - accuracy: 0.8377 - val_loss: 0.9487 - val_accuracy: 0.7000
# Epoch 54/80
# 51/57 [=========================>....] - ETA: 5s - loss: 0.5797 - accuracy: 0.8359
# Epoch 00054: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0054.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.5842 - accuracy: 0.8327 - val_loss: 0.9568 - val_accuracy: 0.6923
# Epoch 55/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.5842 - accuracy: 0.8368 - val_loss: 0.9470 - val_accuracy: 0.6973
# Epoch 56/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.5782 - accuracy: 0.8312 - val_loss: 0.9523 - val_accuracy: 0.6995
# Epoch 57/80
#  8/57 [===>..........................] - ETA: 44s - loss: 0.5743 - accuracy: 0.8369
# Epoch 00057: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0057.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.5792 - accuracy: 0.8357 - val_loss: 0.9570 - val_accuracy: 0.7005
# Epoch 58/80
# 57/57 [==============================] - 64s 1s/step - loss: 0.5694 - accuracy: 0.8394 - val_loss: 0.9488 - val_accuracy: 0.7016
# Epoch 59/80
# 22/57 [==========>...................] - ETA: 31s - loss: 0.5480 - accuracy: 0.8420
# Epoch 00059: saving model to distill_bit_r50x1_224_feature_extraction-plain\cp-0059.ckpt
# 57/57 [==============================] - 65s 1s/step - loss: 0.5645 - accuracy: 0.8390 - val_loss: 0.9560 - val_accuracy: 0.7033

# %%
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 15/15 [==============================] - 13s 842ms/step - loss: 0.9441 - accuracy: 0.7060
# Test Loss: 0.9441371560096741
# Test Accuracy: 0.7060439586639404

# %%
# Visualize training results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']
val_loss_range = range(len(loss))

plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.plot(range(len(loss)), loss, label='Training Loss')
plt.plot(range(len(val_loss)), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.subplot(2, 2, 2)
plt.plot(range(len(acc)), acc, label='Training Accuracy')
plt.plot(range(len(val_acc)), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.show()

# %%
import random

test_files = [
    os.path.join(path, filename)
    for path, _, files in os.walk(test_data_dir)
    for filename in files
    if filename.lower().endswith(".jpg")
]
img_path = Path(random.choice(test_files))

img = tf.keras.preprocessing.image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

pred_y = class_names[np.argmax(score)]
true_y = img_path.parent.stem

plt.figure(figsize=(10, 10))
plt.title(
    f"pred: {pred_y}"
    f"\ntrue: {true_y}"
    f"\nconf: {100 * np.max(score):.2f}%",
    backgroundcolor="green" if pred_y == true_y else "red",
    horizontalalignment='right'
)
plt.imshow(tf.keras.preprocessing.image.load_img(img_path))
plt.axis("off")
# Out:
# (-0.5, 389.5, 279.5, -0.5)
